# %% [markdown]
# # 1. Yolov5 소스 다운로드

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12190, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 12190 (delta 31), reused 23 (delta 5), pack-reused 12124
# Receiving objects: 100% (12190/12190), 12.58 MiB | 25.81 MiB/s, done.
# Resolving deltas: 100% (8379/8379), done.

# %% [markdown]
# # 2. 기본 설치

# %%
# !pip install -qr /content/yolov5/requirements.txt
# Out:
#      |████████████████████████████████| 1.6 MB 5.0 MB/s

# %% [markdown]
# # 3. 학습에 사용할 데이터 다운로드

# %%
# !curl -L "https://universe.roboflow.com/ds/ttE5MUKpQA?key=wwv8ouLzv3" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/images/great_pyrenees_132_jpg.rf.0a9a5c79f56f7997e31cb7fc9d64a304.jpg
#  extracting: train/images/great_pyrenees_133_jpg.rf.751b9b3c732d281cca1483a88cf7a470.jpg
#  extracting: train/images/great_pyrenees_134_jpg.rf.623e6fe9e3a151392e7c61bbc9420d83.jpg
#  extracting: train/images/great_pyrenees_137_jpg.rf.1e3aa18626ba110139205b3d748b692b.jpg
#  extracting: train/images/great_pyrenees_139_jpg.rf.77cada053ebe97f1edba28daffc33bca.jpg
#  extracting: train/images/great_pyrenees_13_jpg.rf.4cb9405124cc27a9a472d009e8a1b45e.jpg
#  extracting: train/images/great_pyrenees_140_jpg.rf.3803bf79ae688f0830ccfa584ea95257.jpg
#  extracting: train/images/great_pyrenees_141_jpg.rf.c39659bc110ba28e502a6211169429d6.jpg
#  extracting: train/images/great_pyrenees_146_jpg.rf.64e11820373c12b6b3007938f60c2431.jpg
#  extracting: train/images/great_pyrenees_147_jpg.rf.3585d934a85a19d6e268d6a513f473e4.jpg
# ...

# %% [markdown]
# # 4. data.yaml 경로 수정

# %% [markdown]
# ```
# train: ../train/images
# val: ../valid/images
#
# 경로수정
#
# train: /content/train/images
# val: /content/valid/images
# ```

# %%
# !python /content/yolov5/train.py \
--img 416 \
--batch 32 \
--epochs 10 \
--data /content/data.yaml \
--weights yolov5x.pt \
--name res-catdog \
--cfg /content/yolov5/models/yolov5x.yaml
# Out:
# train: weights=yolov5x.pt, cfg=/content/yolov5/models/yolov5x.yaml, data=/content/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=res-catdog, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-94-g1aea74c Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# # 6. 테스트 데이터를 이용한 객체 탐지

# %%
# --conf 0.1 : 바운딩 박스로 표기되는 객체 검출 쿼터를 배제 (0.5 이상 표기가 일반적)
# !python /content/yolov5/detect.py \
--weights /content/yolov5/runs/train/res-catdog2/weights/best.pt \
--img 416 \
--source /content/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/res-catdog2/weights/best.pt'], source=/content/test/images, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-94-g1aea74c Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86415658 parameters, 0 gradients, 204.5 GFLOPs
# image 1/356 /content/test/images/Abyssinian_127_jpg.rf.f8d8e346d561d879dfdadf0926eb3ac0.jpg: 416x416 1 cat-Abyssinian, 46.6ms
# image 2/356 /content/test/images/Abyssinian_131_jpg.rf.2b834d3a74897e6b83a0cbbf161fcf78.jpg: 416x416 1 cat-Abyssinian, 1 cat-Sphynx, 36.5ms
# ...

# %% [markdown]
# # 7. 데이터 영상 데이터를 이룔한 객체탐지

# %%
# !python /content/yolov5/detect.py \
--weights /content/yolov5/runs/train/res-catdog2/weights/best.pt \
--source /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# video 1/1 (5786/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.6ms
# video 1/1 (5787/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.3ms
# video 1/1 (5788/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.3ms
# video 1/1 (5789/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.3ms
# video 1/1 (5790/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.3ms
# video 1/1 (5791/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.3ms
# video 1/1 (5792/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.2ms
# video 1/1 (5793/10783) /content/drive/MyDrive/bigDataClass/deeplearning/day3/cat.mp4: 384x640 (no detections), 40.4ms
# ...

# %% [markdown]
# # 8. 모델 백업

# %%
# !cp -r /content/yolov5/runs/train/res-catdog2 /content/drive/MyDrive/bigDataClass/deeplearning/day3/data

# %% [markdown]
# # 9. 응용

# %% [markdown]
# - 통상적으로 opencv와 연계해서 s/w 제작
# - 입력 소스로는
#   - 이미지, 영상, 라이브스트리밍(웹캠, 라이브 방송)
#   - 제품 탐색 -> 쇼핑 추천 연결
#   - 위험 탐지 -> 연기 (화재 탐지), 안전모(산업현장 모니터링)
#   - 응용 -> 사람얼굴 -> 페이스 디텍팅 (opencv에서도 제공) ghlremr -> dlib or mediapipe -> 얼굴 랜드마크 -> 출입/범죄자/실종자/...
